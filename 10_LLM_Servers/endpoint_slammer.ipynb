# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    raise ValueError(
        "FIREWORKS_API_KEY not set. Run: cp .env.example .env and add your Fireworks API key."
    )

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/fireworks/models/gpt-oss-20b"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# That line‑twister is old‑fashioned, but scientists have actually tried to quantify it.
# In 1988, wildlife biologist Richard Thomas estimated that a single woodchuck could move **about 700 pounds (≈320 kg) of soil** in a single day while digging its burrow. If you stretch that to “chuck wood” rather than dig dirt, the rough equivalence is often quoted as **roughly 700 pounds of wood** in the span of a day—though, of course, no one has ever measured a woodchuck actually hauling lumber!
#
# So, in short: a woodchuck could chuck **as much wood as it could chuck when you give it the same effort it uses for moving dirt**—around seven‑hundred pounds per day, give or take, according to that one whimsical study.

# %%
pip install langchain_fireworks
# Out:
# /Users/aaniaadap/Desktop/AI-Eng-Certification/10_LLM_Servers/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

if "llm" not in globals():
    from langchain_fireworks import ChatFireworks

    model_endpoint = "accounts/fireworks/models/gpt-oss-20b"
    llm = ChatFireworks(model=model_endpoint)


async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 12: A classic answer is simply:
#
# > **“A woodchuck would chuck as...
# Response 11: There’s no definitive answer, but the classic tongue‑twister...
# Response 21: Well, according to the “official” wood‑chuck folklore, a woo...
# Response 23: If a wood‑chuck could chuck wood, the classic estimate from ...
# Response 16: The old tongue‑twister never really came with an answer, but...
# Response 14: You’ll have to let your imagination do the heavy lifting, be...
# Response 24: Ah, the classic tongue‑twister! The most up‑to‑date “scienti...
# Response 15: A classic tongue‑twister, and the answer is all in the joke ...
# Response 10: A wood‑chuck, if it were truly capable of chucking timber, w...
# Response 17: It’s just a tongue‑twisting rhyme—no real measurement exists...
# Response 13: The classic chuck‑wood riddle is all in good fun—there’s no ...
# Response 9: **Answer (Request 9)**
#
# There’s no exact “scientific” figu...
# Response 2: **Short answer:** About **700 pounds** of wood a day (roughl...
# Response 6: A classic answer to the tongue‑twister goes something like t...
# Response 3: That classic tongue‑twister isn’t really a question you can ...
# Response 4: **Answer (tongue‑twister edition)**
#
# > If a wood‑chuck cou...
# Response 18: **Answer (in the tongue‑twister spirit)**
# If a woodchuck c...
# Response 5: Sure! Do you want me to give you the answer right now?...
# Response 7: A good old‑fashioned answer is that a woodchuck would chuck ...
# Response 1: **Answer – “Wood‑chuck capacity” (Request 1)**
#
# The classi...
# Response 19: A classic tongue‑twister more than a scientific inquiry, the...
# Response 22: Ah, the classic tongue‑twister question! The truth is—speaki...
# Response 20: **Answer (Request 20)**
# Below is a “menu” of **20 possibl...
# Response 8: rediger span...
